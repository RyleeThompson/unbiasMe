# %%
import sys
from goose3 import Goose
import unicodedata
import tldextract

sys.setrecursionlimit(2500)

def fix(text):
    try:
        text = text.decode("ascii", "ignore")
    except:
        text = text.strip()
        text = text.replace('\n', ' ')
        text = text.replace('\\', '')
        text = text.replace("\r", "")
        text = text.replace("\ufffd'", "")
    return text

def scrape(url):
    g = Goose()
    try:
        article = g.extract(url=url)
    except:
         return "Unexpected error when scraping", sys.exc_info()[0]
    text = fix(article.cleaned_text)
    title = fix(article.title)
    domain = tldextract.extract(url)[1]

    return title, text, domain

# %%
scrape("https://www.cnn.com/2019/11/22/politics/nunes-vienna-trip-ukrainian-prosecutor-biden/index.html")

# %%
import warnings
warnings.filterwarnings("ignore")

import nltk
from nltk import tokenize
import os
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import collections
from nltk.stem.porter import *
from nltk import word_tokenize
from nltk.util import ngrams
import string
import sys
from resources.readability import Readability
import os
import pickle
import json
from importlib import reload

DEFAULT_PATH = os.getcwd()

def setup_path(*args):
    path = os.path.join(*args)
    if not os.path.isdir(path):
        os.makedirs(path)
    return path

def load_acl13_lexicons():
    with open(os.path.join(DEFAULT_PATH, "resources", "bias-lexicon.txt")) as lex:
        bias = set([l.strip() for l in lex])
    with open(os.path.join(DEFAULT_PATH, "resources", "assertives.txt")) as lex:
        assertives = set([l.strip() for l in lex])
    with open(os.path.join(DEFAULT_PATH, "resources", "factives.txt")) as lex:
        factives = set([l.strip() for l in lex])
    with open(os.path.join(DEFAULT_PATH, "resources", "hedges.txt")) as lex:
        hedges = set([l.strip() for l in lex])
    with open(os.path.join(DEFAULT_PATH, "resources", "implicatives.txt")) as lex:
        implicatives = set([l.strip() for l in lex])
    with open(os.path.join(DEFAULT_PATH, "resources", "report_verbs.txt")) as lex:
        report_verbs = set([l.strip() for l in lex])
    with open(os.path.join(DEFAULT_PATH, "resources", "negative-words.txt")) as lex:
        negative = set([l.strip() for l in lex])
    with open(os.path.join(DEFAULT_PATH, "resources", "positive-words.txt")) as lex:
        positive = set([l.strip() for l in lex])
    with open(os.path.join(DEFAULT_PATH, "resources", "subjclueslen.txt")) as lex:
        wneg = set([]);wpos = set([]);wneu = set([]);sneg = set([]);spos = set([]);sneu = set([])
        for line in lex:
            line = line.split()
            if line[0] == "type=weaksubj":
                if line[-1] == "priorpolarity=negative":
                    wneg.add(line[2].split("=")[1])
                elif line[-1] == "priorpolarity=positive":
                    wpos.add(line[2].split("=")[1])
                elif line[-1] == "priorpolarity=neutral":
                    wneu.add(line[2].split("=")[1])
                elif line[-1] == "priorpolarity=both":
                    wneg.add(line[2].split("=")[1])
                    wpos.add(line[2].split("=")[1])
            elif line[0] == "type=strongsubj":
                if line[-1] == "priorpolarity=negative":
                    sneg.add(line[2].split("=")[1])
                elif line[-1] == "priorpolarity=positive":
                    spos.add(line[2].split("=")[1])
                elif line[-1] == "priorpolarity=neutral":
                    sneu.add(line[2].split("=")[1])
                elif line[-1] == "priorpolarity=both":
                    spos.add(line[2].split("=")[1])
                    sneg.add(line[2].split("=")[1])
    return bias, assertives, factives, hedges, implicatives, report_verbs, positive, negative, wneg, wpos, wneu, sneg, spos, sneu

def bias_lexicon_feats(text):
    bias, assertives, factives, hedges, implicatives, report_verbs, positive_op, negative_op, wneg, wpos, wneu, sneg, spos, sneu = load_acl13_lexicons()
    tokens = word_tokenize(text)
    bigrams = [" ".join(bg) for bg in ngrams(tokens, 2)]
    trigrams = [" ".join(tg) for tg in ngrams(tokens, 3)]
    bias_count = float(sum([tokens.count(b) for b in bias]))/len(tokens)
    assertives_count = float(sum([tokens.count(a) for a in assertives]))/len(tokens)
    factives_count = float(sum([tokens.count(f) for f in factives]))/len(tokens)
    hedges_count = sum([tokens.count(h) for h in hedges]) +  sum([bigrams.count(h) for h in hedges]) + sum([trigrams.count(h) for h in hedges])
    hedges_count = float(hedges_count)/len(tokens)
    implicatives_count = float(sum([tokens.count(i) for i in implicatives]))/len(tokens)
    report_verbs_count = float(sum([tokens.count(r) for r in report_verbs]))/len(tokens)
    positive_op_count = float(sum([tokens.count(p) for p in positive_op]))/len(tokens)
    negative_op_count = float(sum([tokens.count(n) for n in negative_op]))/len(tokens)
    wneg_count = float(sum([tokens.count(n) for n in wneg]))/len(tokens)
    wpos_count = float(sum([tokens.count(n) for n in wpos]))/len(tokens)
    wneu_count = float(sum([tokens.count(n) for n in wneu]))/len(tokens)
    sneg_count = float(sum([tokens.count(n) for n in sneg]))/len(tokens)
    spos_count = float(sum([tokens.count(n) for n in spos]))/len(tokens)
    sneu_count = float(sum([tokens.count(n) for n in sneu]))/len(tokens)
    return bias_count, assertives_count, factives_count, hedges_count, implicatives_count, report_verbs_count, positive_op_count, negative_op_count, wneg_count, wpos_count, wneu_count, sneg_count, spos_count, sneu_count

def ttr(text):
    words = text.split()
    dif_words = len(set(words))
    tot_words = len(words)
    if tot_words == 0:
        return 0
    return (float(dif_words)/tot_words)

def POS_features(fn, text, outpath):
    fname = os.path.join(outpath, fn.split(".")[0]+"_tagged.txt")

    pos_tags = ["CC","CD","DT","EX","FW","IN","JJ","JJR","JJS","LS","MD","NN","NNS","NNP","NNPS","PDT","POS","PRP","PRP$","RB","RBR","RBS","RP","SYM","TO","UH","WP$","WRB","VB","VBD","VBG","VBN","VBP","VBZ","WDT","WP"]
    sents = tokenize.sent_tokenize(text)
    counts_norm = []
    allwords = []
    sents = tokenize.sent_tokenize(text)

    with open(fname, "w") as out:
        for sent in sents:
            words = sent.strip(".").split()
            tags = nltk.pos_tag(words)
            strtags = ["/".join((wt[0],wt[1])) for wt in tags]
            out.write("".join(strtags)+" ")

    with open(fname, "r") as fl:
        line = fl.readline() #each file is one line
        
    print(line)

    wordandtag = line.strip().split()
    tags = [wt.split("/")[1] for wt in wordandtag]
    counts = collections.Counter(tags)

    for pt in pos_tags:
        try:
            counts_norm.append(float(counts[pt])/len(tags))
        except:
            counts_norm.append(0)

    return counts_norm

def vadersent(text):
    analyzer = SentimentIntensityAnalyzer()
    vs = analyzer.polarity_scores(text)
    return vs['neg'], vs['neu'], vs['pos']

def readability(text):
    rd = Readability(text)
    fkg_score = rd.FleschKincaidGradeLevel()
    SMOG = rd.SMOGIndex()
    return fkg_score, SMOG

def wordlen_and_stop(text):
    with open(os.path.join(DEFAULT_PATH, "resources", "stopwords.txt")) as data:
        stopwords = [w.strip() for w in data]
    set(stopwords)
    words = word_tokenize(text)
    WC = len(words)
    stopwords_in_text = [s for s in words if s in stopwords]
    percent_sws = float(len(stopwords_in_text))/len(words)
    lengths = [len(w) for w in words if w not in stopwords]
    if len(lengths) == 0:
        word_len_avg = 3
    else:
        word_len_avg = float(sum(lengths))/len(lengths)
    return percent_sws, word_len_avg, WC

def stuff_LIWC_leftout(text):
    puncs = set(string.punctuation)
    tokens = word_tokenize(text)
    quotes = tokens.count("\"")+tokens.count('``')+tokens.count("''")
    Exclaim = tokens.count("!")
    AllPunc = 0
    for p in puncs:
        AllPunc+=tokens.count(p)
    words_upper = 0
    for w in tokens:
        if w.isupper():
            words_upper+=1
    allcaps = float(words_upper)/len(tokens)
    return (float(quotes)/len(tokens))*100, (float(Exclaim)/len(tokens))*100, (float(AllPunc)/len(tokens))*100, allcaps

def subjectivity(text):
    loaded_model = pickle.load(open(os.path.join(DEFAULT_PATH, 'resources', 'NB_Subj_Model.sav'), 'rb'), encoding = 'latin1')
    count_vect = pickle.load(open(os.path.join(DEFAULT_PATH, 'resources', 'count_vect.sav'), 'rb'), encoding = 'latin1')
    tfidf_transformer = pickle.load(open(os.path.join(DEFAULT_PATH, 'resources', 'tfidf_transformer.sav'), 'rb'), encoding = 'latin1')
    X_new_counts = count_vect.transform([text])
    X_new_tfidf = tfidf_transformer.transform(X_new_counts)
    result = loaded_model.predict_proba(X_new_tfidf)
    prob_obj = result[0][0]
    prob_subj = result[0][1]
    return prob_obj, prob_subj

def load_LIWC_dictionaries(filepath=os.path.join(DEFAULT_PATH, "resources")):
    cat_dict = {}
    stem_dict = {}
    counts_dict = {}
    with open(os.path.join(filepath, "LIWC2007_English100131.dic")) as raw:
        raw.readline()
        for line in raw:
            if line.strip() == "%":
                break
            line = line.strip().split()
            cat_dict[line[0]] = line[1]
            counts_dict[line[0]] = 0
        for line in raw:
            line = line.strip().split()
            stem_dict[line[0]] = [l.replace("*", "") for l in line[1:]]
    return cat_dict, stem_dict, counts_dict


def LIWC(text, cat_dict, stem_dict, counts_dict):
    for key in counts_dict:
        counts_dict[key] = 0
    tokens = word_tokenize(text)
    WC = len(tokens)
    stemmer = PorterStemmer()
    stemed_tokens = [stemmer.stem(t) for t in tokens]

    # count and percentage
    for stem in stem_dict:
        count = stemed_tokens.count(stem.replace("*", ""))
        if count > 0:
            for cat in stem_dict[stem]:
                counts_dict[cat] += count
    counts_norm = [float(counts_dict[cat]) / WC * 100 for cat in counts_dict]
    cats = [cat_dict[cat] for cat in cat_dict]
    return counts_norm, cats

def source_encoding(source):
    #load source dictionary
    with open(os.path.join(DEFAULT_PATH, "resources", "source_codes.json")) as j:
        already_encoded_domains = json.loads(j.readline()) #first line is dictionary
        last_code = json.loads(j.readline())[0] #second line is array with single value of last code
    #get source encoding feature
    if source in already_encoded_domains.keys():
        return already_encoded_domains[source]
    else:
        return last_code+1

#def fix(text): # this is just my frustating attempt to fix unicode junk
 #   text = text.replace("\r", "").replace('\n', "").replace("\ufffd'", "")
  #  text = text.decode("ascii", "ignore")
   # return text

def make_str(seq):
    strseq = [str(s) for s in seq]
    return strseq

#main

def start(title_text, text, source, outpath):
    # Setup path function will create the output directory if it does not exist
    pos_features_path = setup_path(outpath, "pos_tagged_files")

    cat_dict, stem_dict, counts_dict = load_LIWC_dictionaries()
    liwc_cats = [cat_dict[cat] for cat in cat_dict]
    pos_tags = ["CC","CD","DT","EX","FW","IN","JJ","JJR","JJS","LS","MD","NN","NNS","NNP","NNPS","PDT","POS","PRP","PRP$","RB","RBR","RBS","RP","SYM","TO","UH","WP$","WRB","VB","VBD","VBG","VBN","VBP","VBZ","WDT","WP"]
    pos_tags_titles = [t+"_title" for t in pos_tags]
    liwc_cats_title = [t+"_title" for t in liwc_cats]
   
    if len(text) == 0:
        raise ValueError("No Text")

    pid = 1

    #source
    source_code = source_encoding(source)
    
    #body
    quotes, Exclaim, AllPunc, allcaps = stuff_LIWC_leftout(text)
    lex_div = ttr(text)
    counts_norm = POS_features("input", text, pos_features_path)
    counts_norm = [str(c) for c in counts_norm]
    counts_norm_liwc, liwc_cats = LIWC(text, cat_dict, stem_dict, counts_dict)
    counts_norm_liwc = [str(c) for c in counts_norm_liwc]
    vadneg, vadneu, vadpos = vadersent(text)
    fke, SMOG = readability(text)
    stop, wordlen, WC = wordlen_and_stop(text)
    NB_pobj, NB_psubj = subjectivity(text)
    bias_count, assertives_count, factives_count, hedges_count, implicatives_count, report_verbs_count, positive_op_count, negative_op_count, wneg_count, wpos_count, wneu_count, sneg_count, spos_count, sneu_count = bias_lexicon_feats(text)

    #title
    quotes_titles, Exclaim_titles, AllPunc_titles, allcaps_titles = stuff_LIWC_leftout(title_text)
    lex_div_title = ttr(title_text)
    counts_norm_title = POS_features("input_title", title_text, pos_features_path)
    counts_norm_title = [str(c) for c in counts_norm]
    counts_norm_liwc_title, liwc_cats_title2 = LIWC(title_text, cat_dict, stem_dict, counts_dict)
    counts_norm_liwc_title = [str(c) for c in counts_norm_liwc_title]
    vadneg_title, vadneu_title, vadpos_title = vadersent(title_text)
    fke_title, SMOG_title = readability(title_text)
    stop_title, wordlen_title, WC_title = wordlen_and_stop(title_text)
    NB_pobj_title, NB_psubj_title = subjectivity(title_text)
    bias_count_title, assertives_count_title, factives_count_title, hedges_count_title, implicatives_count_title, report_verbs_count_title, positive_op_count_title, negative_op_count_title, wneg_count_title, wpos_count_title, wneu_count_title, sneg_count_title, spos_count_title, sneu_count_title = bias_lexicon_feats(title_text)

    with open(os.path.join(outpath, "all_features.csv"), "w") as out:
        seq = ("pid,source_code,bias_count,assertives_count,factives_count,hedges_count,implicatives_count,report_verbs_count,positive_op_count,negative_op_count,wneg_count,wpos_count,wneu_count,sneg_count,spos_count,sneu_count,TTR,vad_neg,vad_neu,vad_pos,FKE,SMOG,stop,wordlen,WC,NB_pobj,NB_psubj,quotes,Exclaim,AllPunc,allcaps",",".join(pos_tags),",".join(liwc_cats), "TTR_title,vad_neg_title,vad_neu_title,vad_pos_title,FKE_title,SMOG_title,stop_title,wordlen_title,WC_title,NB_pobj_title,NB_psubj_title,quotes_title,Exclaim_title,AllPunc_title,allcaps_title",",".join(pos_tags_titles),",".join(liwc_cats_title),"bias_count_title,assertives_count_title,factives_count_title,hedges_count_title,implicatives_count_title,report_verbs_count_title,positive_op_count_title,negative_op_count_title,wneg_count_title,wpos_count_title,wneu_count_title,sneg_count_title,spos_count_title,sneu_count_title")
        out.write(",".join(seq)+"\n")
        seq = (pid, source_code, bias_count, assertives_count, factives_count, hedges_count, implicatives_count, report_verbs_count, positive_op_count, negative_op_count, wneg_count, wpos_count, wneu_count, sneg_count, spos_count, sneu_count, lex_div,vadneg,vadneu,vadpos,fke,SMOG,stop,wordlen,WC,NB_pobj,NB_psubj,quotes,Exclaim,AllPunc,allcaps, ",".join(counts_norm), ",".join(counts_norm_liwc),lex_div_title,vadneg_title,vadneu_title,vadpos_title,fke_title,SMOG_title,stop_title,wordlen_title,WC_title,NB_pobj_title,NB_psubj_title,quotes_titles,Exclaim_titles,AllPunc_titles,allcaps_titles, ",".join(counts_norm_title), ",".join(counts_norm_liwc_title),bias_count_title, assertives_count_title, factives_count_title, hedges_count_title, implicatives_count_title, report_verbs_count_title, positive_op_count_title, negative_op_count_title, wneg_count_title, wpos_count_title, wneu_count_title, sneg_count_title, spos_count_title, sneu_count_title)
        seq = make_str(seq)
        feat_str = ",".join(seq)
        out.write(feat_str + "\n")

# %%
import time
starttime = time.time()
def timeee():
    x = scrape("https://www.cnn.com/2019/11/22/politics/nunes-vienna-trip-ukrainian-prosecutor-biden/index.html")
    start(x[0], x[1], x[2], os.getcwd() + r'\out')
timeee()
end = time.time()
starttime - end
# Out:
# (CNN)/VB A/NNP lawyer/NN for/IN an/DT indicted/JJ associate/NN of/IN Rudy/NNP Giuliani/NNP tells/VBZ CNN/NNP that/IN his/PRP$ client/NN is/VBZ willing/JJ to/TO tell/VB Congress/NNP about/IN meetings/NNS the/DT top/JJ Republican/NNP on/IN the/DT House/NNP Intelligence/NNP Committee/NNP had/VBD in/IN Vienna/NNP last/JJ year/NN with/IN a/DT former/JJ Ukrainian/JJ prosecutor/NN to/TO discuss/VB digging/VBG up/RP dirt/NN on/IN Joe/NNP Biden/NNP The/DT attorney,/NN Joseph/NNP A./NNP Bondy,/NNP represents/VBZ Lev/NNP Parnas,/NNP the/DT recently/RB indicted/VBN Soviet-born/JJ American/NNP who/WP worked/VBD with/IN Giuliani/NNP to/TO push/VB claims/NNS of/IN Democratic/JJ corruption/NN in/IN Ukraine/NNP Bondy/NNP said/VBD that/IN Parnas/NNP was/VBD told/VBN directly/RB by/IN the/DT former/JJ Ukrainian/JJ official/NN that/IN he/PRP met/VBD last/JJ year/NN in/IN Vienna/NNP with/IN Rep./NNP Devin/NNP Nunes/NNP "Mr./JJ Parnas/NNP learned/VBD from/IN former/JJ Ukrainian/JJ Prosecutor/NNP General/NNP Victor/NNP Shokin/NNP that/IN Nunes/NNP had/VBD met/VBN with/IN Shokin/NNP in/IN Vienna/NNP last/JJ December,"/NNP said/VBD Bondy/NNP Shokin/NNP was/VBD ousted/VBN from/IN his/PRP$ position/NN in/IN 2016/CD after/IN pressure/NN from/IN Western/JJ leaders/NNS ,/, including/VBG then-vice/JJ president/NN Biden,/NNP over/IN concerns/NNS that/IN Shokin/NNP was/VBD not/RB pursuing/VBG corruption/NN cases/NNS Nunes/NNS is/VBZ one/CD of/IN President/NNP Donald/NNP Trump's/NNP key/JJ allies/NNS in/IN Congress/NNP and/CC has/VBZ emerged/VBN as/IN a/DT staunch/JJ defender/NN of/IN the/DT President/NNP during/IN the/DT impeachment/NN inquiry,/NN which/WDT he/PRP has/VBZ frequently/RB labeled/VBN as/IN a/DT "circus."/NN Nunes/NNS declined/VBD repeated/JJ requests/NNS for/IN comment/NN Bondy/NNP tells/VBZ CNN/NNP that/IN his/PRP$ client/NN and/CC Nunes/NNP began/VBD communicating/VBG around/IN the/DT time/NN of/IN the/DT Vienna/NNP trip/NN Parnas/NNP says/VBZ he/PRP worked/VBD to/TO put/VB Nunes/NNP in/IN touch/NN with/IN Ukrainians/NNS who/WP could/MD help/VB Nunes/NNP dig/VB up/RP dirt/NN on/IN Biden/NNP and/CC Democrats/NNPS in/IN Ukraine,/NNP according/VBG to/TO Bondy/NNP That/DT information/NN would/MD likely/RB be/VB of/IN great/JJ interest/NN to/TO House/NNP Democrats/NNPS given/VBN its/PRP$ overlap/NN with/IN the/DT current/JJ impeachment/NN inquiry/NN into/IN President/NNP Trump,/NNP and/CC could/MD put/VB Nunes/NNP in/IN a/DT difficult/JJ spot/NN Bondy/NNP tells/VBZ CNN/NNP his/PRP$ client/NN is/VBZ willing/JJ to/TO comply/VB with/IN a/DT Congressional/JJ subpoena/NN for/IN documents/NNS and/CC testimony/NN as/IN part/NN of/IN the/DT impeachment/NN inquiry/NN in/IN a/DT manner/NN that/WDT would/MD allow/VB him/PRP to/TO protect/VB his/PRP$ Fifth/NNP Amendment/NNP rights/NNS against/IN self-incrimination/NN Those/DT revelations/NNS came/VBD to/TO a/DT head/NN on/IN Thursday/NNP when/WRB Democratic/NNP Rep./NNP Eric/NNP Swalwell/NNP raised/VBD the/DT Daily/NNP Beast/NNP story/NN publicly/RB during/IN the/DT impeachment/NN hearing/NN Parnas,/NN who/WP was/VBD indicted/VBN on/IN federal/JJ campaign/NN finance/NN charges/NNS last/JJ month,/JJ worked/VBD with/IN Shokin/NNP and/CC Giuliani/NNP to/TO push/VB a/DT pair/NN of/IN unfounded/JJ claims:/NN that/WDT Ukrainians/VBZ interfered/VBN in/IN the/DT 2016/CD election/NN on/IN behalf/NN of/IN Democrats,/NNP and/CC that/IN Biden/NNP was/VBD acting/VBG corruptly/RB in/IN Ukraine/NNP on/IN behalf/NN of/IN his/PRP$ son/NN Hunter,/NNP who/WP sat/VBD on/IN the/DT board/NN of/IN Ukrainian/NNP gas/NN company/NN Burisma/NNP Holdings/NNS According/VBG to/TO Bondy,/NNP Parnas/NNP claims/VBZ Nunes/NNP worked/VBD to/TO push/VB similar/JJ allegations/NNS of/IN Democratic/JJ corruption/NN "Nunes/NNS had/VBD told/VBN Shokin/NNP of/IN the/DT urgent/JJ need/NN to/TO launch/VB investigations/NNS into/IN Burisma,/NNP Joe/NNP and/CC Hunter/NNP Biden,/NNP and/CC any/DT purported/JJ Ukrainian/JJ interference/NN in/IN the/DT 2016/ ...
# Exclusive:/NNP Giuliani/NNP associate/NN willing/JJ to/TO tell/VB Congress/NNP Nunes/NNP met/VBD with/IN ex-Ukrainian/JJ official/NN to/TO get/VB dirt/NN on/IN Biden/NNP
# -1.8969779014587402

# %%
import pandas as pd
df = pd.read_csv('NELA.csv')

# %%
df2 = pd.read_csv('all_features.csv')

# %%
cols = df2.columns
cols = [x.strip() for x in cols]
notin = []
i = 0
for col in df.columns:
    if col.strip() not in cols:
        i += 1
        print(col)
        notin.append(col)
print(i)

# %%
df.drop([' source', ' date'], axis = 1, inplace = True)

# %%
notin.remove(' source')

# %%
notin.remove(' date')

# %%
for col in notin:
    print(df.columns.get_loc(col))

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\User\Documents\HackHarvard\file.json"

# %%
from googleapiclient.discovery import build
import pprint


def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search(
    'poo', my_api_key, my_cse_id, num=10)
for result in results:
    pprint.pprint(result)

# %%
res['queries']['nextPage']

# %%
res['items'][0]['link']

# %%
def get_urls(query, numResults):
    my_api_key = "AIzaSyB5j2lTK4tVJsPTWmwXJ5ypn1Hojjh-RdU"
    my_cse_id = "011673657838978336298:dqh43ak8nfj"
    
    service = build("customsearch", "v1", developerKey = my_api_key)
    urls = []
    for i in range(0, numResults, 10):
        numres = min(numResults - i, 10)
        results = service.cse().list(q = query, cx = my_cse_id, start = i + 1, num = numres).execute()
        for res in results['items']:
            urls.append(res['link'])
    return urls

# %%
def search(query, numResults):
    urls = get_urls(query, numResults)
    for url in urls:
        scrape(url)

# %%
import application
# Out:
# ['(CNN)/VB', 'A/NNP', 'lawyer/NN', 'for/IN', 'an/DT', 'indicted/JJ', 'associate/NN', 'of/IN', 'Rudy/NNP', 'Giuliani/NNP', 'tells/VBZ', 'CNN/NNP', 'that/IN', 'his/PRP$', 'client/NN', 'is/VBZ', 'willing/JJ', 'to/TO', 'tell/VB', 'Congress/NNP', 'about/IN', 'meetings/NNS', 'the/DT', 'top/JJ', 'Republican/NNP', 'on/IN', 'the/DT', 'House/NNP', 'Intelligence/NNP', 'Committee/NNP', 'had/VBD', 'in/IN', 'Vienna/NNP', 'last/JJ', 'year/NN', 'with/IN', 'a/DT', 'former/JJ', 'Ukrainian/JJ', 'prosecutor/NN', 'to/TO', 'discuss/VB', 'digging/VBG', 'up/RP', 'dirt/NN', 'on/IN', 'Joe/NNP', 'Biden/NNP']
# asdfas
# (CNN)/VBA/NNPlawyer/NNfor/INan/DTindicted/JJassociate/NNof/INRudy/NNPGiuliani/NNPtells/VBZCNN/NNPthat/INhis/PRP$
# ['The/DT', 'attorney,/NN', 'Joseph/NNP', 'A./NNP', 'Bondy,/NNP', 'represents/VBZ', 'Lev/NNP', 'Parnas,/NNP', 'the/DT', 'recently/RB', 'indicted/VBN', 'Soviet-born/JJ', 'American/NNP', 'who/WP', 'worked/VBD', 'with/IN', 'Giuliani/NNP', 'to/TO', 'push/VB', 'claims/NNS', 'of/IN', 'Democratic/JJ', 'corruption/NN', 'in/IN', 'Ukraine/NNP']
# asdfas
# The/DTattorney,/NNJoseph/NNPA./NNPBondy,/NNPrepresents/VBZLev/NNPParnas,/NNPthe/DTrecently/RBindicted/VBNSoviet-born/JJAmerican/NNPwho/WPworked/VBDwith/INGiuliani/NNPto/TOpush/VBclaims/NNSof/INDemocratic/JJcorruption/NNin/INUkraine/NNP
# ['Bondy/NNP', 'said/VBD', 'that/IN', 'Parnas/NNP', 'was/VBD', 'told/VBN', 'directly/RB', 'by/IN', 'the/DT', 'former/JJ', 'Ukrainian/JJ', 'official/NN', 'that/IN', 'he/PRP', 'met/VBD', 'last/JJ', 'year/NN', 'in/IN', 'Vienna/NNP', 'with/IN', 'Rep./NNP', 'Devin/NNP', 'Nunes/NNP']
# asdfas
# Bondy/NNPsaid/VBDthat/INParnas/NNPwas/VBDtold/VBNdirectly/RBby/INthe/DTformer/JJUkrainian/JJofficial/NNthat/INhe/PRPmet/VBDlast/JJyear/NNin/INVienna/NNPwith/INRep./NNPDevin/NNPNunes/NNP
# ['"Mr./JJ', 'Parnas/NNP', 'learned/VBD', 'from/IN', 'former/JJ', 'Ukrainian/JJ', 'Prosecutor/NNP', 'General/NNP', 'Victor/NNP', 'Shokin/NNP', 'that/IN', 'Nunes/NNP', 'had/VBD', 'met/VBN', 'with/IN', 'Shokin/NNP', 'in/IN', 'Vienna/NNP', 'last/JJ', 'December,"/NNP', 'said/VBD', 'Bondy/NNP']
# asdfas
# "Mr./JJParnas/NNPlearned/VBDfrom/INformer/JJUkrainian/JJProsecutor/NNPGeneral/NNPVictor/NNPShokin/NNPthat/INNunes/NNPhad/VBDmet/VBNwith/INShokin/NNPin/INVienna/NNPlast/JJDecember,"/NNPsaid/VBDBondy/NNP
# ['Shokin/NNP', 'was/VBD', 'ousted/VBN', 'from/IN', 'his/PRP$', 'position/NN', 'in/IN', '2016/CD', 'after/IN', 'pressure/NN', 'from/IN', 'Western/JJ', 'leaders/NNS', ',/,', 'including/VBG', 'then-vice/JJ', 'president/NN', 'Biden,/NNP', 'over/IN', 'concerns/NNS', 'that/IN', 'Shokin/NNP', 'was/VBD', 'not/RB', 'pursuing/VBG', 'corruption/NN', 'cases/NNS']
# asdfas
# Shokin/NNPwas/VBDousted/VBNfrom/INhis/PRP$position/NNin/IN2016/CDafter/INpressure/NNfrom/INWestern/JJleaders/NNS,/,including/VBGthen-vice/JJpresident/NNBiden,/NNPover/INconcerns/NNSthat/INShokin/NNPwas/VBDnot/RBpursuing/VBGcorruption/NNcases/NNS
# ['Nunes/NNS', 'is/VBZ', 'one/CD', 'of/IN', 'President/NNP', 'Donald/NNP', "Trump's/NNP", 'key/JJ', 'allies/NNS', 'in/IN', 'Congress/NNP', 'and/CC', 'has/VBZ', 'emerged/VBN', 'as/IN', 'a/DT', 'staunch/JJ', 'defender/NN', 'of/IN', 'the/DT', 'President/NNP', 'during/IN', 'the/DT', 'impeachment/NN', 'inquiry,/NN', 'which/WDT', 'he/PRP', 'has/VBZ', 'frequently/RB', 'labeled/VBN', 'as/IN', 'a/DT', '"circus."/NN']
# asdfas
# Nunes/NNSis/VBZone/CDof/INPresident/NNPDonald/NNPTrump's/NNPkey/JJallies/NNSin/INCongress/NNPand/CChas/VBZemerged/VBNas/INa/DTstaunch/JJdefender/NNof/INthe/DTPresident/NNPduring/INthe/DTimpeachment/NNinquiry,/NNwhich/WDThe/PRPhas/VBZfrequently/RBlabeled/VBNas/INa/DT"circus."/NN
# ['Nunes/NNS', 'declined/VBD', 'repeated/JJ', 'requests/NNS', 'for/IN', 'comment/NN']
# asdfas
# Nunes/NNSdeclined/VBDrepeated/JJrequests/NNSfor/INcomment/NN
# ['Bondy/NNP', 'tells/VBZ', 'CNN/NNP', 'that/IN', 'his/PRP$', 'client/NN', 'and/CC', 'Nunes/NNP', 'began/VBD', 'communicating/VBG', 'around/IN', 'the/DT', 'time/NN', 'of/IN', 'the/DT', 'Vienna/NNP', 'trip/NN']
# asdfas
# Bondy/NNPtells/VBZCNN/NNPthat/INhis/PRP$client/NNand/CCNunes/NNPbegan/VBDcommunicating/VBGaround/INthe/DTtime/NNof/INthe/DTVienna/NNPtrip/NN
# ['Parnas/NNP', 'says/VBZ', 'he/PRP', 'worked/VBD', 'to/TO', 'put/VB', 'Nunes/NNP', 'in/IN', 'touch/NN', 'with/IN', 'Ukrainians/NNS', 'who/WP', 'could/MD', 'help/VB', 'Nunes/NNP', 'dig/VB', 'up/RP', 'dirt/NN', 'on/IN', 'Biden/NNP', 'and/CC', 'Democrats/NNPS', 'in/IN', 'Ukraine,/NNP', 'according/VBG', 'to/TO', 'Bondy/NNP']
# asdfas
# Parnas/NNPsays/VBZhe/PRPworked/VBDto/TOput/VBNunes/NNPin/INtouch/NNwith/INUkrainians/NNSwho/WPcould/MDhelp/VBNunes/NNPdig/VBup/RPdirt/NNon/INBiden/NNPand/CCDemocrats/NNPSin/INUkraine,/NNPaccording/VBGto/TOBondy/NNP
# ['That/DT', 'information/NN', 'would/MD', 'likely/RB', 'be/VB', 'of/IN', 'great/JJ', 'interest/NN', 'to/TO', 'House/NNP', 'Democrats/NNPS', 'given/VBN', 'its/PRP$', 'overlap/NN', 'with/IN', 'the/DT', 'current/JJ', 'impeachment/NN', 'inquiry/NN', 'into/IN', 'President/NNP', 'Trump,/NNP', 'and/CC', 'could/MD', 'put/VB', 'Nunes/NNP', 'in/IN', 'a/DT', 'difficult/JJ', 'spot/NN']
# asdfas
# That/DTinformation/NNwould/MDlikely/RBbe/VBof/INgreat/JJinterest/NNto/TOHouse/NNPDemocrats/NNPSgiven/VBNits/PRP$overlap/NNwith/INthe/DTcurrent/JJimpeachment/NNinquiry/NNinto/INPresident/NNPTrump,/NNPand/CCcould/MDput/VBNunes/NNPin/INa/DTdifficult/JJspot/NN
# ['Bondy/NNP', 'tells/VBZ', 'CNN/NNP', 'his/PRP$', 'client/NN', 'is/VBZ', 'willing/JJ', 'to/TO', 'comply/VB', 'with/IN', 'a/DT', 'Congressional/JJ', 'subpoena/NN', 'for/IN', 'documents/NNS', 'and/CC', 'testimony/NN', 'as/IN', 'part/NN', 'of/IN', 'the/DT', 'impeachment/NN', 'inquiry/NN', 'in/IN', 'a/DT', 'manner/NN', 'that/WDT', 'would/MD', 'allow/VB', 'him/PRP', 'to/TO', 'protect/VB', 'his/PRP$', 'Fifth/NNP', 'Amendment/NNP', 'rights/NNS', 'against/IN', 'self-incrimination/NN']
# asdfas
# Bondy/NNPtells/VBZCNN/NNPhis/PRP$client/NNis/VBZwilling/JJto/TOcomply/VBwith/INa/DTCongressional/JJsubpoena/NNfor/INdocuments/NNSand/CCtestimony/NNas/INpart/NNof/INthe/DTimpeachment/NNinquiry/NNin/INa/DTmanner/NNthat/WDTwould/MDallow/VBhim/PRPto/TOprotect/VBhis/PRP$Fifth/NNPAmendment/NNPrights/NNSagainst/INself-incrimination/NN
# ['Those/DT', 'revelations/NNS', 'came/VBD', 'to/TO', 'a/DT', 'head/NN', 'on/IN', 'Thursday/NNP', 'when/WRB', 'Democratic/NNP', 'Rep./NNP', 'Eric/NNP', 'Swalwell/NNP', 'raised/VBD', 'the/DT', 'Daily/NNP', 'Beast/NNP', 'story/NN', 'publicly/RB', 'during/IN', 'the/DT', 'impeachment/NN', 'hearing/NN']
# asdfas
# Those/DTrevelations/NNScame/VBDto/TOa/DThead/NNon/INThursday/NNPwhen/WRBDemocratic/NNPRep./NNPEric/NNPSwalwell/NNPraised/VBDthe/DTDaily/NNPBeast/NNPstory/NNpublicly/RBduring/INthe/DTimpeachment/NNhearing/NN
# ['Parnas,/NN', 'who/WP', 'was/VBD', 'indicted/VBN', 'on/IN', 'federal/JJ', 'campaign/NN', 'finance/NN', 'charges/NNS', 'last/JJ', 'month,/JJ', 'worked/VBD', 'with/IN', 'Shokin/NNP', 'and/CC', 'Giuliani/NNP', 'to/TO', 'push/VB', 'a/DT', 'pair/NN', 'of/IN', 'unfounded/JJ', 'claims:/NN', 'that/WDT', 'Ukrainians/VBZ', 'interfered/VBN', 'in/IN', 'the/DT', '2016/CD', 'election/NN', 'on/IN', 'behalf/NN', 'of/IN', 'Democrats,/NNP', 'and/CC', 'that/IN', 'Biden/NNP', 'was/VBD', 'acting/VBG', 'corruptly/RB', 'in/IN', 'Ukraine/NNP', 'on/IN', 'behalf/NN', 'of/IN', 'his/PRP$', 'son/NN', 'Hunter,/NNP', 'who/WP', 'sat/VBD', 'on/IN', 'the/DT', 'board/NN', 'of/IN', 'Ukrainian/NNP', 'gas/NN', 'company/NN', 'Burisma/NNP', 'Holdings/NNS']
# asdfas
# Parnas,/NNwho/WPwas/VBDindicted/VBNon/INfederal/JJcampaign/NNfinance/NNcharges/NNSlast/JJmonth,/JJworked/VBDwith/INShokin/NNPand/CCGiuliani/NNPto/TOpush/VBa/DTpair/NNof/INunfounded/JJclaims:/NNthat/WDTUkrainians/VBZinterfered/VBNin/INthe/DT2016/CDelection/NNon/INbehalf/NNof/INDemocrats,/NNPand/CCthat/INBiden/NNPwas/VBDacting/VBGcorruptly/RBin/INUkraine/NNPon/INbehalf/NNof/INhis/PRP$son/NNHunter,/NNPwho/WPsat/VBDon/INthe/DTboard/NNof/INUkrainian/NNPgas/NNcompany/NNBurisma/NNPHoldings/NNS
# ['According/VBG', 'to/TO', 'Bondy,/NNP', 'Parnas/NNP', 'claims/VBZ', 'Nunes/NNP', 'worked/VBD', 'to/TO', 'push/VB', 'similar/JJ', 'allegations/NNS', 'of/IN', 'Democratic/JJ', 'corruption/NN']
# asdfas
# According/VBGto/TOBondy,/NNPParnas/NNPclaims/VBZNunes/NNPworked/VBDto/TOpush/VBsimilar/JJallegations/NNSof/INDemocratic/JJcorruption/NN
# ['"Nunes/NNS', 'had/VBD', 'told/VBN', 'Shokin/NNP', 'of/IN', 'the/DT', 'urgent/JJ', 'need/NN', 'to/TO', 'launch/VB', 'investigations/NNS', 'into/IN', 'Burisma,/NNP', 'Joe/NNP', 'and/CC', 'Hunter/NNP', 'Biden,/NNP', 'and/CC', 'any/DT', 'purported/JJ', 'Ukrainian/JJ', 'interference/NN', 'in/IN', 'the/DT', '2016/CD', 'election,"/NN', 'Bondy/NNP', 'told/VBD', 'CNN/NNP']
# asdfas
# "Nunes/NNShad/VBDtold/VBNShokin/NNPof/INthe/DTurgent/JJneed/NNto/TOlaunch/VBinvestigations/NNSinto/INBurisma,/NNPJoe/NNPand/CCHunter/NNPBiden,/NNPand/CCany/DTpurported/JJUkrainian/JJinterference/NNin/INthe/DT2016/CDelection,"/NNBondy/NNPtold/VBDCNN/NNP
# ['There/EX', 'is/VBZ', 'no/DT', 'evidence/NN', 'that/IN', 'the/DT', 'Bidens/NNP', 'acted/VBD', 'inappropriately/RB']
# asdfas
# There/EXis/VBZno/DTevidence/NNthat/INthe/DTBidens/NNPacted/VBDinappropriately/RB
# ['Nor/CC', 'is/VBZ', 'there/RB', 'evidence/NN', 'to/TO', 'support/VB', 'the/DT', 'conspiracy/NN', 'theory/NN', 'that/WDT', 'Ukraine/NNP', 'worked/VBD', 'with/IN', 'Democrats/NNPS', 'to/TO', 'interfere/VB', 'in/IN', 'the/DT', '2016/CD', 'election/NN']
# asdfas
# Nor/CCis/VBZthere/RBevidence/NNto/TOsupport/VBthe/DTconspiracy/NNtheory/NNthat/WDTUkraine/NNPworked/VBDwith/INDemocrats/NNPSto/TOinterfere/VBin/INthe/DT2016/CDelection/NN
# ['Yet/RB', 'these/DT', 'claims/NNS', 'have/VBP', 'been/VBN', 'a/DT', 'key/JJ', 'part/NN', 'of/IN', 'the/DT', 'public/JJ', 'defense/NN', 'of/IN', 'the/DT', 'President/NNP', 'put/VBD', 'forth/RP', 'by/IN', 'Nunes/NNS', 'and/CC', 'other/JJ', 'Republicans/NNPS', 'during/IN', 'the/DT', 'impeachment/JJ', 'hearings/NNS', 'this/DT', 'month/NN']
# asdfas
# Yet/RBthese/DTclaims/NNShave/VBPbeen/VBNa/DTkey/JJpart/NNof/INthe/DTpublic/JJdefense/NNof/INthe/DTPresident/NNPput/VBDforth/RPby/INNunes/NNSand/CCother/JJRepublicans/NNPSduring/INthe/DTimpeachment/JJhearings/NNSthis/DTmonth/NN
# ['Parnas/NNP', 'is/VBZ', 'currently/RB', 'under/IN', 'house/NN', 'arrest/NN', 'in/IN', 'Florida/NNP', 'and/CC', 'has/VBZ', 'pleaded/VBN', 'not/RB', 'guilty/JJ', 'to/TO', 'charges/NNS', 'of/IN', 'federal/JJ', 'campaign/NN', 'finance/NN', 'fraud/NN']
# asdfas
# Parnas/NNPis/VBZcurrently/RBunder/INhouse/NNarrest/NNin/INFlorida/NNPand/CChas/VBZpleaded/VBNnot/RBguilty/JJto/TOcharges/NNSof/INfederal/JJcampaign/NNfinance/NNfraud/NN
# ['Over/IN', 'the/DT', 'past/JJ', 'two/CD', 'weeks,/NN', 'CNN/NNP', 'approached/VBD', 'Nunes/NNS', 'on/IN', 'two/CD', 'occasions/NNS', 'and/CC', 'reached/VBD', 'out/RP', 'to/TO', 'his/PRP$', 'communications/NNS', 'staff/NN', 'to/TO', 'get/VB', 'comment/NN', 'for/IN', 'this/DT', 'story/NN']
# asdfas
# Over/INthe/DTpast/JJtwo/CDweeks,/NNCNN/NNPapproached/VBDNunes/NNSon/INtwo/CDoccasions/NNSand/CCreached/VBDout/RPto/TOhis/PRP$communications/NNSstaff/NNto/TOget/VBcomment/NNfor/INthis/DTstory/NN
# ['In/IN', 'the/DT', 'Capitol/NNP', 'on/IN', 'Nov./NNP', '14,/CD', 'as/IN', 'CNN/NNP', 'began/VBD', 'to/TO', 'ask/VB', 'a/DT', 'question/NN', 'about/IN', 'the/DT', 'trip/NN', 'to/TO', 'Vienna,/NNP', 'Nunes/NNP', 'interjected/VBD', 'and/CC', 'said,/JJ', '"I/NN', "don't/NN", 'talk/NN', 'to/TO', 'you/PRP', 'in/IN', 'this/DT', 'lifetime/NN', 'or/CC', 'the/DT', 'next/JJ', 'lifetime."/NN']
# asdfas
# In/INthe/DTCapitol/NNPon/INNov./NNP14,/CDas/INCNN/NNPbegan/VBDto/TOask/VBa/DTquestion/NNabout/INthe/DTtrip/NNto/TOVienna,/NNPNunes/NNPinterjected/VBDand/CCsaid,/JJ"I/NNdon't/NNtalk/NNto/TOyou/PRPin/INthis/DTlifetime/NNor/CCthe/DTnext/JJlifetime."/NN
# ['"At/VB', 'any/DT', 'time,"/JJ', 'Nunes/NNP', 'added/VBD']
# asdfas
# "At/VBany/DTtime,"/JJNunes/NNPadded/VBD
# ['"On/VB', 'any/DT', 'question."/NN']
# asdfas
# "On/VBany/DTquestion."/NN
# ['Asked/VBN', 'again/RB', 'on/IN', 'Thursday/NNP', 'about/IN', 'his/PRP$', 'travel/NN', 'to/TO', 'Vienna/NNP', 'and/CC', 'his/PRP$', 'interactions/NNS', 'with/IN', 'Shokin/NNP', 'and/CC', 'Parnas,/NNP', 'Nunes/NNP', 'gave/VBD', 'a/DT', 'similar/JJ', 'response/NN']
# asdfas
# Asked/VBNagain/RBon/INThursday/NNPabout/INhis/PRP$travel/NNto/TOVienna/NNPand/CChis/PRP$interactions/NNSwith/INShokin/NNPand/CCParnas,/NNPNunes/NNPgave/VBDa/DTsimilar/JJresponse/NN
# ['"To/RB', 'be/VB', 'perfectly/RB', 'clear,/JJ', 'I/PRP', "don't/VBP", 'acknowledge/VB', 'any/DT', 'questions/NNS', 'from/IN', 'you/PRP', 'in/IN', 'this/DT', 'lifetime/NN', 'or/CC', 'the/DT', 'next/JJ', 'lifetime,"/NN', 'Nunes/NNP', 'said/VBD', 'while/IN', 'leaving/VBG', 'the/DT', 'impeachment/NN', 'hearing/NN']
# asdfas
# "To/RBbe/VBperfectly/RBclear,/JJI/PRPdon't/VBPacknowledge/VBany/DTquestions/NNSfrom/INyou/PRPin/INthis/DTlifetime/NNor/CCthe/DTnext/JJlifetime,"/NNNunes/NNPsaid/VBDwhile/INleaving/VBGthe/DTimpeachment/NNhearing/NN
# ['"I/NN', "don't/NNS", 'acknowledge/VBP', 'any/DT', 'question/NN', 'from/IN', 'you/PRP', 'ever."/VBP']
# asdfas
# "I/NNdon't/NNSacknowledge/VBPany/DTquestion/NNfrom/INyou/PRPever."/VBP
# ['CNN/NNP', 'was/VBD', 'unable/JJ', 'to/TO', 'reach/VB', 'Shokin/NNP', 'for/IN', 'comment/NN']
# asdfas
# CNN/NNPwas/VBDunable/JJto/TOreach/VBShokin/NNPfor/INcomment/NN
# ["Nunes'/NNP", 'entourage/NN', 'included/VBD', 'retired/JJ', 'colonel/NNS', 'Derek/NNP', 'Harvey,/NNP', 'who/WP', 'had/VBD', 'previously/RB', 'worked/VBN', 'for/IN', 'Trump/NNP', 'on/IN', 'the/DT', 'National/NNP', 'Security/NNP', 'Council,/NNP', 'and/CC', 'now/RB', 'works/VBZ', 'for/IN', 'Nunes/NNS', 'on/IN', 'the/DT', 'House/NNP', 'Intelligence/NNP', 'Committee/NNP']
# asdfas
# Nunes'/NNPentourage/NNincluded/VBDretired/JJcolonel/NNSDerek/NNPHarvey,/NNPwho/WPhad/VBDpreviously/RBworked/VBNfor/INTrump/NNPon/INthe/DTNational/NNPSecurity/NNPCouncil,/NNPand/CCnow/RBworks/VBZfor/INNunes/NNSon/INthe/DTHouse/NNPIntelligence/NNPCommittee/NNP
# ['Harvey/NNP', 'declined/VBD', 'to/TO', 'comment/VB']
# asdfas
# Harvey/NNPdeclined/VBDto/TOcomment/VB
# ['Bondy/NNP', 'told/VBD', 'CNN/NNP', 'that/IN', 'Nunes/NNP', 'planned/VBD', 'the/DT', 'trip/NN', 'to/TO', 'Vienna/NNP', 'after/IN', 'Republicans/NNPS', 'lost/VBD', 'control/NN', 'of/IN', 'the/DT', 'House/NNP', 'in/IN', 'the/DT', 'mid-term/JJ', 'elections/NNS', 'on/IN', 'Nov./NNP', '6,/CD', '2018/CD']
# asdfas
# Bondy/NNPtold/VBDCNN/NNPthat/INNunes/NNPplanned/VBDthe/DTtrip/NNto/TOVienna/NNPafter/INRepublicans/NNPSlost/VBDcontrol/NNof/INthe/DTHouse/NNPin/INthe/DTmid-term/JJelections/NNSon/INNov./NNP6,/CD2018/CD
# ['"Mr./JJ', 'Parnas/NNP', 'learned/VBD', 'through/IN', "Nunes'/NNP", 'investigator,/NN', 'Derek/NNP', 'Harvey,/NNP', 'that/IN', 'the/DT', 'Congressman/NNP', 'had/VBD', 'sequenced/VBN', 'this/DT', 'trip/NN', 'to/TO', 'occur/VB', 'after/IN', 'the/DT', 'mid-term/JJ', 'elections/NNS', 'yet/RB', 'before/IN', "Congress'/NNP", 'return/NN', 'to/TO', 'session,/VB', 'so/RB', 'that/IN', 'Nunes/NNP', 'would/MD', 'not/RB', 'have/VB', 'to/TO', 'disclose/VB', 'the/DT', 'trip/NN', 'details/NNS', 'to/TO', 'his/PRP$', 'Democrat/NNP', 'colleagues/NNS', 'in/IN', 'Congress,"/NNP', 'said/VBD', 'Bondy/NNP']
# asdfas
# "Mr./JJParnas/NNPlearned/VBDthrough/INNunes'/NNPinvestigator,/NNDerek/NNPHarvey,/NNPthat/INthe/DTCongressman/NNPhad/VBDsequenced/VBNthis/DTtrip/NNto/TOoccur/VBafter/INthe/DTmid-term/JJelections/NNSyet/RBbefore/INCongress'/NNPreturn/NNto/TOsession,/VBso/RBthat/INNunes/NNPwould/MDnot/RBhave/VBto/TOdisclose/VBthe/DTtrip/NNdetails/NNSto/TOhis/PRP$Democrat/NNPcolleagues/NNSin/INCongress,"/NNPsaid/VBDBondy/NNP
# ['At/IN', 'the/DT', 'time/NN', 'of/IN', 'the/DT', 'trip,/NN', 'Nunes/NNP', 'was/VBD', 'chairman/NN', 'of/IN', 'the/DT', 'Intelligence/NNP', 'Committee/NNP']
# asdfas
# At/INthe/DTtime/NNof/INthe/DTtrip,/NNNunes/NNPwas/VBDchairman/NNof/INthe/DTIntelligence/NNPCommittee/NNP
# ['In/IN', 'January,/NNP', 'Democratic/NNP', 'Rep./NNP', 'Adam/NNP', 'Schiff/NNP', 'took/VBD', 'over/RP', 'as/IN', 'chairman/NN', 'of/IN', 'the/DT', 'powerful/JJ', 'committee,/NN', 'which/WDT', 'is/VBZ', 'now/RB', 'conducting/VBG', 'the/DT', 'impeachment/NN', 'inquiry/NN']
# asdfas
# In/INJanuary,/NNPDemocratic/NNPRep./NNPAdam/NNPSchiff/NNPtook/VBDover/RPas/INchairman/NNof/INthe/DTpowerful/JJcommittee,/NNwhich/WDTis/VBZnow/RBconducting/VBGthe/DTimpeachment/NNinquiry/NN
# ['Bondy/NNP', 'says/VBZ', 'that/IN', 'according/VBG', 'to/TO', 'his/PRP$', 'client,/NN', 'following/VBG', 'a/DT', 'brief/JJ', 'in-person/JJ', 'meeting/NN', 'in/IN', 'late/JJ', '2018,/CD', 'Parnas/NNPS', 'and/CC', 'Nunes/NNPS', 'had/VBD', 'at/IN', 'least/JJS', 'two/CD', 'more/JJR', 'phone/NN', 'conversations,/NN', 'and/CC', 'that/IN', 'Nunes/NNP', 'instructed/VBD', 'Parnas/NNP', 'to/TO', 'work/VB', 'with/IN', 'Harvey/NNP', 'on/IN', 'the/DT', 'Ukraine/NNP', 'matters/NNS']
# asdfas
# Bondy/NNPsays/VBZthat/INaccording/VBGto/TOhis/PRP$client,/NNfollowing/VBGa/DTbrief/JJin-person/JJmeeting/NNin/INlate/JJ2018,/CDParnas/NNPSand/CCNunes/NNPShad/VBDat/INleast/JJStwo/CDmore/JJRphone/NNconversations,/NNand/CCthat/INNunes/NNPinstructed/VBDParnas/NNPto/TOwork/VBwith/INHarvey/NNPon/INthe/DTUkraine/NNPmatters/NNS
# ['Parnas/NNP', 'says/VBZ', 'that/IN', 'shortly/RB', 'after/IN', 'the/DT', 'Vienna/NNP', 'trip,/NN', 'he/PRP', 'and/CC', 'Harvey/NNP', 'met/VBD', 'at/IN', 'the/DT', 'Trump/NNP', 'International/NNP', 'Hotel/NNP', 'in/IN', 'Washington,/NNP', 'where/WRB', 'they/PRP', 'discussed/VBD', 'claims/NNS', 'about/IN', 'the/DT', 'Bidens/NNP', 'as/RB', 'well/RB', 'as/IN', 'allegations/NNS', 'of/IN', 'Ukrainian/JJ', 'election/NN', 'interference,/NN', 'according/VBG', 'to/TO', 'Bondy/NNP']
# asdfas
# Parnas/NNPsays/VBZthat/INshortly/RBafter/INthe/DTVienna/NNPtrip,/NNhe/PRPand/CCHarvey/NNPmet/VBDat/INthe/DTTrump/NNPInternational/NNPHotel/NNPin/INWashington,/NNPwhere/WRBthey/PRPdiscussed/VBDclaims/NNSabout/INthe/DTBidens/NNPas/RBwell/RBas/INallegations/NNSof/INUkrainian/JJelection/NNinterference,/NNaccording/VBGto/TOBondy/NNP
# ['Following/VBG', 'this,/NN', 'Bondy/NNP', 'says/VBZ', 'that/IN', 'in/IN', 'a/DT', 'phone/NN', 'conversation/NN', 'Nunes/NNP', 'told/VBD', 'Parnas/NNP', 'that/IN', 'he/PRP', 'was/VBD', 'conducting/VBG', 'his/PRP$', 'own/JJ', 'investigation/NN', 'into/IN', 'the/DT', 'Bidens/NNP', 'and/CC', 'asked/VBD', 'Parnas/NNP', 'for/IN', 'help/NN', 'validating/VBG', 'information/NN', "he'd/NN", 'gathered/VBN', 'from/IN', 'conversations/NNS', 'with/IN', 'various/JJ', 'current/JJ', 'and/CC', 'former/JJ', 'Ukrainian/JJ', 'officials,/NN', 'including/VBG', 'Shokin/NNP']
# asdfas
# Following/VBGthis,/NNBondy/NNPsays/VBZthat/INin/INa/DTphone/NNconversation/NNNunes/NNPtold/VBDParnas/NNPthat/INhe/PRPwas/VBDconducting/VBGhis/PRP$own/JJinvestigation/NNinto/INthe/DTBidens/NNPand/CCasked/VBDParnas/NNPfor/INhelp/NNvalidating/VBGinformation/NNhe'd/NNgathered/VBNfrom/INconversations/NNSwith/INvarious/JJcurrent/JJand/CCformer/JJUkrainian/JJofficials,/NNincluding/VBGShokin/NNP
# ['Parnas/NNP', 'says/VBZ', 'that/IN', 'Nunes/NNP', 'told/VBD', 'him/PRP', "he'd/VB", 'been/VBN', 'partly/RB', 'working/VBG', 'off/IN', 'of/IN', 'information/NN', 'from/IN', 'the/DT', 'journalist/NN', 'John/NNP', 'Solomon,/NNP', 'who/WP', 'had/VBD', 'written/VBN', 'a/DT', 'number/NN', 'of/IN', 'articles/NNS', 'on/IN', 'the/DT', 'Biden/NNP', 'conspiracy/NN', 'theory/NN', 'for/IN', 'the/DT', 'Hill,/NNP', 'according/VBG', 'to/TO', 'Bondy/NNP']
# asdfas
# Parnas/NNPsays/VBZthat/INNunes/NNPtold/VBDhim/PRPhe'd/VBbeen/VBNpartly/RBworking/VBGoff/INof/INinformation/NNfrom/INthe/DTjournalist/NNJohn/NNPSolomon,/NNPwho/WPhad/VBDwritten/VBNa/DTnumber/NNof/INarticles/NNSon/INthe/DTBiden/NNPconspiracy/NNtheory/NNfor/INthe/DTHill,/NNPaccording/VBGto/TOBondy/NNP
# ['CNN/NNP', 'reached/VBD', 'out/RP', 'to/TO', 'Harvey/NNP', 'on/IN', 'multiple/JJ', 'occasions/NNS', 'for/IN', 'comment/NN']
# asdfas
# CNN/NNPreached/VBDout/RPto/TOHarvey/NNPon/INmultiple/JJoccasions/NNSfor/INcomment/NN
# ['Reached/VBN', 'by/IN', 'phone/NN', 'on/IN', 'Friday/NNP', 'morning,/NNP', 'Harvey/NNP', 'refused/VBD', 'to/TO', 'comment/VB', 'and/CC', 'directed/VBD', 'CNN/NNP', 'to/TO', 'contact/VB', 'the/DT', 'communications/NNS', 'director/NN', 'for/IN', 'Nunes/NNS']
# asdfas
# Reached/VBNby/INphone/NNon/INFriday/NNPmorning,/NNPHarvey/NNPrefused/VBDto/TOcomment/VBand/CCdirected/VBDCNN/NNPto/TOcontact/VBthe/DTcommunications/NNSdirector/NNfor/INNunes/NNS
# ['That/DT', 'person,/VBZ', 'Jack/NNP', 'Langer,/NNP', 'did/VBD', 'not/RB', 'respond/VB', 'to/TO', 'numerous/JJ', 'requests/NNS', 'for/IN', 'comment/NN', 'from/IN', 'CNN/NNP']
# asdfas
# That/DTperson,/VBZJack/NNPLanger,/NNPdid/VBDnot/RBrespond/VBto/TOnumerous/JJrequests/NNSfor/INcomment/NNfrom/INCNN/NNP
# ['A/DT', 'spokesman/NN', 'for/IN', 'Schiff/NN', 'declined/VBD', 'to/TO', 'comment/VB', 'for/IN', 'this/DT', 'story/NN']
# asdfas
# A/DTspokesman/NNfor/INSchiff/NNdeclined/VBDto/TOcomment/VBfor/INthis/DTstory/NN
# ['Bondy/NNP', 'tells/VBZ', 'CNN/NNP', 'that/IN', 'Parnas/NNP', 'is/VBZ', 'also/RB', 'willing/JJ', 'to/TO', 'tell/VB', 'Congress/NNP', 'about/IN', 'a/DT', 'series/NN', 'of/IN', 'regular/JJ', 'meetings/NNS', 'he/PRP', 'says/VBZ', 'he/PRP', 'took/VBD', 'part/NN', 'in/IN', 'at/IN', 'the/DT', 'Trump/NNP', 'International/NNP', 'Hotel/NNP', 'in/IN', 'Washington/NNP', 'that/WDT', 'concerned/VBD', 'Ukraine/NNP']
# asdfas
# 
# ['According/VBG', 'to/TO', 'Bondy,/NNP', 'Parnas/NNP', 'became/VBD', 'part/NN', 'of/IN', 'what/WP', 'he/PRP', 'described/VBD', 'as/IN', 'a/DT', '"team"/NN', 'that/WDT', 'met/VBD', 'several/JJ', 'times/NNS', 'a/DT', 'week/NN', 'in/IN', 'a/DT', 'private/JJ', 'room/NN', 'at/IN', 'the/DT', 'BLT/NNP', 'restaurant/NN', 'on/IN', 'the/DT', 'second/JJ', 'floor/NN', 'of/IN', 'the/DT', 'Trump/NNP', 'Hotel/NNP']
# asdfas
# According/VBGto/TOBondy,/NNPParnas/NNPbecame/VBDpart/NNof/INwhat/WPhe/PRPdescribed/VBDas/INa/DT"team"/NNthat/WDTmet/VBDseveral/JJtimes/NNSa/DTweek/NNin/INa/DTprivate/JJroom/NNat/INthe/DTBLT/NNPrestaurant/NNon/INthe/DTsecond/JJfloor/NNof/INthe/DTTrump/NNPHotel/NNP
# ['In/IN', 'addition/NN', 'to/TO', 'giving/VBG', 'the/DT', 'group/NN', 'access/NN', 'to/TO', 'key/JJ', 'people/NNS', 'in/IN', 'Ukraine/NNP', 'who/WP', 'could/MD', 'help/VB', 'their/PRP$', 'cause,/NN', 'Parnas/NNP', 'translated/VBD', 'their/PRP$', 'conversations,/NN', 'Bondy/NNP', 'said/VBD']
# asdfas
# In/INaddition/NNto/TOgiving/VBGthe/DTgroup/NNaccess/NNto/TOkey/JJpeople/NNSin/INUkraine/NNPwho/WPcould/MDhelp/VBtheir/PRP$cause,/NNParnas/NNPtranslated/VBDtheir/PRP$conversations,/NNBondy/NNPsaid/VBD
# ['The/DT', 'group,/NN', 'according/VBG', 'to/TO', 'Bondy,/NNP', 'included/VBD', 'Giuliani,/NNP', 'Parnas,/NNP', 'the/DT', 'journalist/NN', 'Solomon,/NNP', 'and/CC', 'the/DT', 'married/JJ', 'attorneys/NNS', 'Joe/NNP', 'diGenova/NN', 'and/CC', 'Victoria/NNP', 'Toensing/NNP']
# asdfas
# The/DTgroup,/NNaccording/VBGto/TOBondy,/NNPincluded/VBDGiuliani,/NNPParnas,/NNPthe/DTjournalist/NNSolomon,/NNPand/CCthe/DTmarried/JJattorneys/NNSJoe/NNPdiGenova/NNand/CCVictoria/NNPToensing/NNP
# ['Parnas/NNP', 'said/VBD', 'that/IN', 'Harvey/NNP', 'would/MD', 'occasionally/RB', 'be/VB', 'present/JJ', 'as/IN', 'well,/NN', 'and/CC', 'that/IN', 'it/PRP', 'was/VBD', "Parnas'/NNP", 'understanding/VBG', 'that/IN', 'Harvey/NNP', 'was/VBD', "Nunes'/NNP", 'proxy,/NN', 'Bondy/NNP', 'said/VBD']
# asdfas
# Parnas/NNPsaid/VBDthat/INHarvey/NNPwould/MDoccasionally/RBbe/VBpresent/JJas/INwell,/NNand/CCthat/INit/PRPwas/VBDParnas'/NNPunderstanding/VBGthat/INHarvey/NNPwas/VBDNunes'/NNPproxy,/NNBondy/NNPsaid/VBD
# ['Solomon/NNP', 'confirmed/VBD', 'the/DT', 'meetings/NNS', 'to/TO', 'CNN/NNP', 'but/CC', 'said/VBD', 'that/IN', 'calling/VBG', 'the/DT', 'group/NN', 'a/DT', 'team/NN', 'was/VBD', 'a/DT', 'bit/NN', 'of/IN', 'a/DT', 'mischaracterization/NN']
# asdfas
# Solomon/NNPconfirmed/VBDthe/DTmeetings/NNSto/TOCNN/NNPbut/CCsaid/VBDthat/INcalling/VBGthe/DTgroup/NNa/DTteam/NNwas/VBDa/DTbit/NNof/INa/DTmischaracterization/NN
# ['Solomon/NNP', 'said/VBD', 'that/IN', 'connectivity/NN', 'happened/VBD', 'more/RBR', 'organically,/JJ', 'and/CC', 'that/IN', 'his/PRP$', 'role/NN', 'was/VBD', 'only/RB', 'as/IN', 'a/DT', 'journalist/NN', 'reporting/VBG', 'a/DT', 'story/NN']
# asdfas
# Solomon/NNPsaid/VBDthat/INconnectivity/NNhappened/VBDmore/RBRorganically,/JJand/CCthat/INhis/PRP$role/NNwas/VBDonly/RBas/INa/DTjournalist/NNreporting/VBGa/DTstory/NN
# ['Solomon/NNP', 'also/RB', 'said/VBD', 'that/IN', 'Di/NNP', 'Genova/NNP', 'and/CC', 'Toensing,/NNP', 'his/PRP$', 'lawyers,/NN', 'introduced/VBD', 'him/PRP', 'to/TO', 'Parnas/NNP', 'as/IN', 'a/DT', 'facilitator/NN', 'and/CC', 'interpreter/NN', 'in/IN', 'early/JJ', 'March/NNP']
# asdfas
# Solomon/NNPalso/RBsaid/VBDthat/INDi/NNPGenova/NNPand/CCToensing,/NNPhis/PRP$lawyers,/NNintroduced/VBDhim/PRPto/TOParnas/NNPas/INa/DTfacilitator/NNand/CCinterpreter/NNin/INearly/JJMarch/NNP
# ['"Parnas/NN', 'was/VBD', 'very/RB', 'helpful/JJ', 'to/TO', 'me/PRP', 'in/IN', 'getting/VBG', 'Ukraine/NNP', 'officials/NNS', 'on/IN', 'the/DT', 'record,"/NN', 'Solomon/NNP', 'told/VBD', 'CNN/NNP']
# asdfas
# "Parnas/NNwas/VBDvery/RBhelpful/JJto/TOme/PRPin/INgetting/VBGUkraine/NNPofficials/NNSon/INthe/DTrecord,"/NNSolomon/NNPtold/VBDCNN/NNP
# ['"I/NN', 'only/RB', 'gradually/RB', 'realized/VBN', 'Lev/NNP', 'was/VBD', 'working/VBG', 'for/IN', 'other/JJ', 'people,/NN', 'including/VBG', 'Rudy/NNP', 'Giuliani."/NNP']
# asdfas
# "I/NNonly/RBgradually/RBrealized/VBNLev/NNPwas/VBDworking/VBGfor/INother/JJpeople,/NNincluding/VBGRudy/NNPGiuliani."/NNP
# ['Solomon/JJ', 'insists/NNS', 'he/PRP', 'was/VBD', 'only/RB', 'reporting/VBG', 'on/IN', 'a/DT', 'story/NN', 'as/IN', 'it/PRP', 'unfolded,/VBZ', '"Any/JJ', 'suggestion/NN', 'that/IN', 'I/PRP', 'was/VBD', 'involved/VBN', 'in/IN', 'any/DT', 'campaign/NN', 'to/TO', 'pressure/VB', 'Ukraine/NNP', 'or/CC', 'the/DT', 'United/NNP', 'States/NNPS', 'government/NN', 'to/TO', 'take/VB', 'any/DT', 'actions/NNS', 'is/VBZ', 'categorically/RB', 'false,"/JJ', 'Solomon/NNP', 'said/VBD']
# asdfas
# Solomon/JJinsists/NNShe/PRPwas/VBDonly/RBreporting/VBGon/INa/DTstory/NNas/INit/PRPunfolded,/VBZ"Any/JJsuggestion/NNthat/INI/PRPwas/VBDinvolved/VBNin/INany/DTcampaign/NNto/TOpressure/VBUkraine/NNPor/CCthe/DTUnited/NNPStates/NNPSgovernment/NNto/TOtake/VBany/DTactions/NNSis/VBZcategorically/RBfalse,"/JJSolomon/NNPsaid/VBD
# ['Giuliani/NNP', 'did/VBD', 'not/RB', 'respond/VB', 'to/TO', 'requests/NNS', 'for/IN', 'comment/NN']
# asdfas
# Giuliani/NNPdid/VBDnot/RBrespond/VBto/TOrequests/NNSfor/INcomment/NN
# ['DiGenova/NNP', 'and/CC', 'Toensing/NNP', 'declined/VBD', 'to/TO', 'comment/VB', 'through/IN', 'a/DT', 'spokesperson/NN']
# asdfas
# DiGenova/NNPand/CCToensing/NNPdeclined/VBDto/TOcomment/VBthrough/INa/DTspokesperson/NN
# ['In/IN', 'the/DT', 'weeks/NNS', 'since/IN', 'his/PRP$', 'arrest,/NN', 'Parnas/NNP', 'has/VBZ', 'become/VBN', 'disenchanted/VBN', 'with/IN', 'Trump/NNP', 'and/CC', 'Giuliani,/NNP', 'according/VBG', 'to/TO', 'Bondy/NNP', 'as/RB', 'well/RB', 'as/IN', 'other/JJ', 'sources/NNS', 'who/WP', 'spoke/VBD', 'to/TO', 'CNN/VB']
# asdfas
# In/INthe/DTweeks/NNSsince/INhis/PRP$arrest,/NNParnas/NNPhas/VBZbecome/VBNdisenchanted/VBNwith/INTrump/NNPand/CCGiuliani,/NNPaccording/VBGto/TOBondy/NNPas/RBwell/RBas/INother/JJsources/NNSwho/WPspoke/VBDto/TOCNN/VB
# ['Parnas,/NNP', 'these/DT', 'sources/NNS', 'say,/VBP', 'was/VBD', 'particularly/RB', 'upset/VBN', 'when/WRB', 'Trump/NNP', 'denied/VBD', 'knowing/VBG', 'him/PRP', 'the/DT', 'day/NN', 'after/IN', 'Parnas/NNP', 'and/CC', 'his/PRP$', 'associate/JJ', 'Igor/NNP', 'Fruman/NNP', 'were/VBD', 'arrested/VBN', 'in/IN', 'October/NNP']
# asdfas
# Parnas,/NNPthese/DTsources/NNSsay,/VBPwas/VBDparticularly/RBupset/VBNwhen/WRBTrump/NNPdenied/VBDknowing/VBGhim/PRPthe/DTday/NNafter/INParnas/NNPand/CChis/PRP$associate/JJIgor/NNPFruman/NNPwere/VBDarrested/VBNin/INOctober/NNP
# ['"He/NN', 'believes/VBZ', 'he/PRP', 'has/VBZ', 'put/VBN', 'himself/PRP', 'out/IN', 'there/RB', 'for/IN', 'the/DT', 'President/NNP', 'and/CC', 'now/RB', "he's/VBP", 'been/VBN', 'completely/RB', 'hung/VBN', 'out/RP', 'to/TO', 'dry,"/VB', 'a/DT', 'person/NN', 'close/JJ', 'to/TO', 'Parnas/NNP', 'told/VBD', 'CNN/NNP']
# asdfas
# "He/NNbelieves/VBZhe/PRPhas/VBZput/VBNhimself/PRPout/INthere/RBfor/INthe/DTPresident/NNPand/CCnow/RBhe's/VBPbeen/VBNcompletely/RBhung/VBNout/RPto/TOdry,"/VBa/DTperson/NNclose/JJto/TOParnas/NNPtold/VBDCNN/NNP
# ['Last/JJ', 'week,/VBD', 'the/DT', 'White/NNP', 'House/NNP', 'did/VBD', 'not/RB', 'respond/VB', 'to/TO', 'repeated/VB', 'requests/NNS', 'for/IN', 'comment/NN', 'to/TO', 'a/DT', 'series/NN', 'of/IN', 'questions/NNS', 'regarding/VBG', 'the/DT', 'meeting/NN', 'and/CC', "Trump's/NNP", 'relationship/NN', 'with/IN', 'Parnas/NNP']
# asdfas
# Last/JJweek,/VBDthe/DTWhite/NNPHouse/NNPdid/VBDnot/RBrespond/VBto/TOrepeated/VBrequests/NNSfor/INcomment/NNto/TOa/DTseries/NNof/INquestions/NNSregarding/VBGthe/DTmeeting/NNand/CCTrump's/NNPrelationship/NNwith/INParnas/NNP
# ['On/IN', 'Thursday,/NNP', 'Bondy/NNP', 'promoted/VBD', 'the/DT', 'hashtag/NN', '#LetLevSpeak/NN', 'on/IN', 'Twitter/NNP', 'in/IN', 'response/NN', 'to/TO', 'a/DT', 'number/NN', 'of/IN', 'questions/NNS', 'about/IN', 'whether/IN', 'Parnas/NNP', 'would/MD', 'testify/VB', 'in/IN', 'front/NN', 'of/IN', 'Congress/NNP']
# asdfas
# On/INThursday,/NNPBondy/NNPpromoted/VBDthe/DThashtag/NN#LetLevSpeak/NNon/INTwitter/NNPin/INresponse/NNto/TOa/DTnumber/NNof/INquestions/NNSabout/INwhether/INParnas/NNPwould/MDtestify/VBin/INfront/NNof/INCongress/NNP
# ['Exclusive:/NNP', 'Giuliani/NNP', 'associate/NN', 'willing/JJ', 'to/TO', 'tell/VB', 'Congress/NNP', 'Nunes/NNP', 'met/VBD', 'with/IN', 'ex-Ukrainian/JJ', 'official/NN', 'to/TO', 'get/VB', 'dirt/NN', 'on/IN', 'Biden/NNP']
# asdfas
# Exclusive:/NNPGiuliani/NNPassociate/NNwilling/JJto/TOtell/VBCongress/NNPNunes/NNPmet/VBDwith/INex-Ukrainian/JJofficial/NNto/TOget/VBdirt/NNon/INBiden/NNP
# 1.9581670761108398
